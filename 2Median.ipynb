# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_excel("C:/Users/sumit/Downloads/ESD-1.xlsx")

# %%
dataset.isnull().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        915
# dtype: int64

# %%
np.median(dataset["Age"])
# Out:
# np.float64(45.0)

# %%
md=np.median(dataset["Age"])

# %%
sns.histplot(x="Age",data=dataset)
plt.plot([md for i in range(0,120)],[i for i in range(0,120)],c="red")
plt.show()
